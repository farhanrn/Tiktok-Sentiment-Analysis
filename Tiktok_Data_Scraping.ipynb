# %%
pip install google-play-scraper

# %%
from google_play_scraper import reviews_all, Sort

# Scrape reviews for TikTok app in Indonesian (ID) from Indonesia
try:
    tiktok_reviews = reviews_all(
        'com.ss.android.ugc.trill',  # TikTok app ID
        lang='id',                   # Set to Indonesian language
        country='id',                # Set to Indonesia
        sort=Sort.MOST_RELEVANT,      # Sort by most relevant reviews
        count= 1000000
    )

    # Print or process the reviews
    print(tiktok_reviews[:5])  # Display first 5 reviews as a sample

except Exception as e:
    print("An error occurred:", e)
# Out:
# [{'reviewId': 'd4a3fbf4-efe6-482b-b1e1-3bfbd08a9fee', 'userName': 'Pengguna Google', 'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g', 'content': 'Hai tiktok, aplikasi anda sangat bagus, namun fitur di dalamnya masih kurang, seperti pemilihan resolusi, pengaturan otomatis resolusi (hemat data) untuk menghemat paket data. Dan tambahlah fitur untuk "jangan rekomendasikan channel" supaya pengguna lebih nyaman dengan kontenlainnya. Serta tambahlah fitur "jangan play video sebelum diputar" untuk meringankan device yang kurang mumpuni.', 'score': 3, 'thumbsUpCount': 0, 'reviewCreatedVersion': None, 'at': datetime.datetime(2024, 5, 22, 2, 1, 17), 'replyContent': None, 'repliedAt': None, 'appVersion': None}, {'reviewId': '1cdd269f-f595-48ad-8908-2fae90cdd039', 'userName': 'Pengguna Google', 'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nu
# ...

# %%
# Menyimpan ulasan dalam file CSV
import csv

with open('tiktok_review.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in tiktok_reviews:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
import pandas as pd
app_reviews_df = pd.DataFrame(tiktok_reviews)
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('tiktok_review_data.csv', index=False)

# %%
# Membuat DataFrame dari hasil scrapreview
app_reviews_df = pd.DataFrame(tiktok_reviews)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  d4a3fbf4-efe6-482b-b1e1-3bfbd08a9fee  Pengguna Google
# 1  1cdd269f-f595-48ad-8908-2fae90cdd039  Pengguna Google
# 2  694a792e-122e-4285-b6fe-de58d822d541  Pengguna Google
# 3  3c9e74dc-a52e-47b1-a495-e98dede4eedb  Pengguna Google
# 4  700f88c1-b404-4e4a-98ec-575ac35c1ac0  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Hai tiktok, aplikasi anda sangat bagus, namun ...      3              0
# 1  Gak membosankan, video menarik, resolusi video...      5           1579
# ...

# %%
app_reviews_df.shape
# Out:
# (108000, 11)
